# %% [markdown]
# # twee2vec
# https://github.com/KavelCortex/twee2vec
#
# using tweepy to crawl specific user's twitter, then use word2vec to vectorize the user.

# %% [markdown]
# ## load models
# It might take a few minutes to load the model. Usually, loading one model is enough since loading all of them takes significant amount of memories (26GB+ if fully loaded).

# %%
import utils.model as model
model_crawl=model.load_crawl()
#model_googlenews=model.load_googlenews()

# %%
model_crawl.similar_by_word('reddit')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   if __name__ == '__main__':
# [('Reddit', 0.7779529094696045),
#  ('reddit.com', 0.7500296831130981),
#  ('reddits', 0.7445194125175476),
#  ('sub-reddit', 0.7283133268356323),
#  ('redditors', 0.7057265043258667),
#  ('redditor', 0.7045639753341675),
#  ('subreddit', 0.6930303573608398),
#  ('reddit.', 0.6882845163345337),
#  ('reddit.com.', 0.6651791334152222),
#  ('subreddits', 0.644948422908783)]

# %%
model_googlenews.similar_by_word('reddit')
# Out:
# [('retweet_button', 0.6663103103637695),
#  ('Ma.gnolia', 0.6655329465866089),
#  ('TechMeme', 0.6617240309715271),
#  ('digg.com', 0.6613273620605469),
#  ('Reddit_Digg', 0.6520460844039917),
#  ('TwitterTwitter', 0.6511324048042297),
#  ('digg', 0.6493878364562988),
#  ('reblog', 0.6416275501251221),
#  ('MyBlogLog', 0.6226954460144043),
#  ('Digg', 0.6219328045845032)]

# %% [markdown]
# ## Vectorize user

# %%
import importlib
importlib.reload(vectorizer)
vector=vectorizer.vectorize_user(model=model_crawl,screen_name='alsareini',limit=200)
vector
# Out:
# array([ 5.17624588e+01, -3.93024025e+01,  5.04298019e+01,  1.02697086e+01,
#         1.42654076e+01, -4.16912880e+01,  7.59431305e+01, -2.32086430e+01,
#         8.29691315e+00, -1.57460761e+00, -9.78250504e+00, -1.77803822e+01,
#        -1.62177348e+00, -7.47384131e-01, -2.64708252e+01,  1.07032537e+01,
#         6.56296873e+00, -1.70643449e+00, -7.04803324e+00,  4.56503181e+01,
#        -2.79940987e+01,  2.24025536e+01,  1.36678019e+01,  2.29434624e+01,
#        -5.99647827e+01,  2.33146119e+00, -3.98501968e+01,  1.56074800e+01,
#        -4.53872252e+00,  1.56255615e+00,  3.68813777e+00, -2.64131336e+01,
#        -4.07755518e+00, -1.82738037e+01,  3.01412487e+01,  2.29688091e+01,
#         1.04416685e+01, -5.64311445e-01,  8.97394562e+00,  1.57709780e+01,
#        -2.85078907e+01, -8.57217178e+01, -1.15893593e+01, -5.23591614e+00,
#        -2.46083393e+01,  8.25210648e+01, -1.00094910e+01,  1.71896863e+00,
# ...
